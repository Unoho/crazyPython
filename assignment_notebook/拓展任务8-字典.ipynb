# %% [markdown]
# # 任务一：网络爬虫方向  电子书类别统计
#
# <b>目标：</b>
#
# 我们已经从在线书店获得图书畅销榜的图书信息，包括书名、作者、价格、类别，现在需要根据类别对数量进行统计，并且计算不同类别的平均价格。
# 数据集：爬取的数据存储"图书畅销榜.csv"文件中。
#
# 编写代码，完成以下任务

# %% [markdown]
# ## 1.加载数据

# %%
# 直接执行，使用Pandas读取数据
import pandas as pd
df = pd.read_csv('图书畅销榜.csv')

# %%
# 直接执行，预览数据
df

# %% [markdown]
# ## 2.统计并使用字典存储数据

# %%
# 按类别统计图书数量和平均价格，结构为{'类别':{'数量':数量},{'平均价格':价格}}
# Todo 从此处开始输入你的代码

# %% [markdown]
# 正确结果如下图所示
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.字典排序

# %%
# 分别根据类别数量、平均价格进行排序
# Todo 从此处开始输入你的代码

# %% [markdown]
# # 任务二：数据分析方向  销售数据统计

# %% [markdown]
# <b>目标：</b>
# 使用Python字典存储销售数据。进行简单数据分析，计算总销售额、平均销售额。
#
# 数据集：你有一个CSV文件(customer_shopping_data.csv)，其中包含以下列：发票号码、顾客ID、顾客性别、顾客年龄、商品类别、顾客购买商品数量、支付总金额、支付方式、发票日期。
#
# 编写代码，完成以下任务

# %% [markdown]
# ## 1.加载数据

# %%
# 导入模块
import pandas as pd
from datetime import datetime
# 使用Pandas读取数据
df = pd.read_csv('customer_shopping_data.csv')

# 预览数据
df

# %% [markdown]
# ## 2.数据转换

# %%
# 使用to_datetime将日期列转换为日期类型，设置format参数为'%d/%m/%Y'
# Todo 从此处开始输入你的代码

# %% [markdown]
# 转换后效果如下图所示
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.使用字典存储数据

# %%
# 按照发票日期分组统计销售金额。
# Todo 从此处开始输入你的代码

# %% [markdown]
# 输出效果如下图所示
# ![image.png](attachment:image.png)

# %%
# 将统计结果转换为字典
# Todo 从此处开始输入你的代码

# %% [markdown]
# 输出结果如下图所示
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4.根据销售总金额对字典进行排序

# %%
# 找出销售额最高的前10个日期及销售额。
# Todo 从此处开始输入你的代码

# %% [markdown]
# 输出结果如下图所示
# ![image.png](attachment:image.png)
